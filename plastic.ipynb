# %% [markdown]
# <a href="https://colab.research.google.com/github/Karthick-ng/DL_river_plastic/blob/main/plastic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="8PmKE7lnezZGqlFq7yxm")
project = rf.workspace("mylab").project("thai_laos")
dataset = project.version(1).download("yolov8")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 1.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 7.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 22.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 9.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 18.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 9.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.2/72.2 kB 11.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 8.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.1
#     Uninstalling pyparsing-3.1.1:
#       Successfully uninstalled pyparsing-3.1.1
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.8.1.78
# ...

# %%
root_dir=r"/content/thai_laos-1"

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 644.7/644.7 kB 10.2 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import os
model = YOLO("yolov8n.pt")  # build a new model from scratch
model.train(data=os.path.join(root_dir,'data.yaml'), epochs=40, batch=16,cache=True)  # train the model
# Out:
# Ultralytics YOLOv8.0.201 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
import locale
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding
# !zip -r /content/file.zip /content/runs
# Out:
#   adding: content/runs/ (stored 0%)
#   adding: content/runs/detect/ (stored 0%)
#   adding: content/runs/detect/train/ (stored 0%)
#   adding: content/runs/detect/train/P_curve.png (deflated 14%)
#   adding: content/runs/detect/train/F1_curve.png (deflated 18%)
#   adding: content/runs/detect/train/results.csv (deflated 85%)
#   adding: content/runs/detect/train/val_batch1_labels.jpg (deflated 7%)
#   adding: content/runs/detect/train/train_batch1321.jpg (deflated 7%)
#   adding: content/runs/detect/train/train_batch1322.jpg (deflated 7%)
#   adding: content/runs/detect/train/val_batch1_pred.jpg (deflated 7%)
#   adding: content/runs/detect/train/events.out.tfevents.1698242109.5ef738835c39.440.1 (deflated 83%)
#   adding: content/runs/detect/train/train_batch2.jpg (deflated 1%)
#   adding: content/runs/detect/train/val_batch0_labels.jpg (deflated 7%)
#   adding: content/runs/detect/train/train_batch1320.jpg (deflated 6%)
# ...

# %%
model.predict("/content/file20_95.png",save=True)
# Out:
# image 1/1 /content/file20_95.png: 640x640 2 0s, 16.6ms
# Speed: 3.0ms preprocess, 16.6ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/train4
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: '0'}
#  orig_img: array([[[ 64,  66,  63],
#          [ 58,  61,  59],
#          [ 35,  37,  37],
#          ...,
#          [145, 156, 173],
#          [155, 171, 187],
#          [154, 171, 187]],
#
#         [[ 67,  68,  64],
#          [ 63,  65,  63],
#          [ 45,  47,  47],
#          ...,
#          [118, 129, 146],
#          [142, 155, 171],
#          [139, 156, 172]],
#
#         [[ 65,  68,  65],
#          [ 57,  59,  58],
#          [ 56,  58,  57],
#          ...,
#          [112, 123, 140],
#          [110, 123, 140],
#          [115, 131, 147]],
#
#         ...,
#
#         [[ 67,  75,  82],
# ...
